# %% [markdown]
# **# VLOG ANALYSIS (WITH NO AUDIO VOICEOVER)**

# %%
import cv2
import google.generativeai as genai
from google.generativeai import GenerativeModel, GenerationConfig
from transformers import BlipProcessor, BlipForConditionalGeneration 
import torch

# Configure Gemini API Key
genai.configure(api_key="API KEY") 

# Function to Extract Scene Descriptions
def extract_scene_descriptions(video_path, frame_interval=30):
    """
    Extracts scene descriptions from video frames.
    :param video_path: Path to the video file.
    :param frame_interval: Number of frames to skip between analyses.
    :return: List of scene descriptions.
    """
    video = cv2.VideoCapture(video_path)
    processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
    model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)

    frame_count = 0
    scene_descriptions = []
    success, frame = video.read()

    while success:
        if frame_count % frame_interval == 0: 
            # Convert frame to RGB format
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Convert to PIL image for BLIP
            pil_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            inputs = processor(pil_frame, return_tensors="pt").to(device)
            caption = model.generate(**inputs)
            description = processor.decode(caption[0], skip_special_tokens=True)
            scene_descriptions.append(description)

        frame_count += 1
        success, frame = video.read()

    video.release()
    return scene_descriptions

# Path to Video and Extract Descriptions
video_path = "/kaggle/input/video-data/Japan Cinematic Travel Video _ Grand Escape Weathering With You Music _ Discover Japan in 4 K.mp4"  
print("Extracting scene descriptions...")
scenes = extract_scene_descriptions(video_path)
print("\nScene Descriptions:")
print(scenes)

# Prepare Input for Gemini 1.5 Pro
MODEL_ID = "gemini-1.5-pro-002"
model_bot = GenerativeModel(
    MODEL_ID,
    system_instruction=[
        "You are an insightful assistant analyzing video scenes.",
        "Your mission is to extract meaningful insights from video scene descriptions."
    ],
)

generation_config = GenerationConfig(
    temperature=0.7,
    top_p=0.9,
    top_k=30,
    candidate_count=1,
    max_output_tokens=8192,
)

contents = [
    f"""
You are a travel expert analyzing scene descriptions from a video.  Provide a structured summary of the travel destinations and experiences depicted. For each place/activity, include:

* **Name:** The name of the place or activity (if identifiable; otherwise, a descriptive label).
* **Description:** A brief description (2-3 sentences) based on the visual scenes.
* **Type:** Categorize as City, Hotel, Experience, Activity, Landmark,  or Other.
* **Relevant Information:** Based on the "Type," provide the following:
    * **City:** Best time to visit, type of traveler who would enjoy it, potential local cuisine.
    * **Hotel:**  Potential amenities (inferred from visuals), target audience (e.g., families, couples), overall vibe.
    * **Experience/Activity:** Best time to participate, who might enjoy it.
    * **Landmark:** Historical or cultural significance, key features.
    * **Other:** Any other relevant observations.

If information is not clearly depicted in the scenes, use "Not specified" or make reasonable assumptions based on the visuals.  Focus on creating a concise and informative travel guide based on the video content.


Scene Descriptions:
{scenes}
"""
]

# Generate Analysis Using Gemini
print("\nAnalyzing scenes with Gemini...")
response = model_bot.generate_content(
    contents=contents,
    generation_config=generation_config,
)

# Display Analysis Results
if response.candidates:
    analysis_text = response.candidates[0].content.parts[0].text
    print("\nAnalysis Results:")
    print(analysis_text)
else:
    print("No candidates found in the response.")
# Out:
# Extracting scene descriptions...
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Scene Descriptions:
# ['a black background with a white and red flower', 'a view of a pagoda tower in the middle of a city', 'a pagoda tower in the middle of a city', 'a pagoda tower in the middle of a city', 'a pagoda tower in the middle of a city', 'a pagoda tower with a mountain in the background', 'a green field with a blue sky in the background', 'a green field with a blue sky in the background', 'a green field with a blue sky in the background', 'a tree with pink flowers in the sky', 'a tree with red flowers in the sun', 'a tree with red flowers in the sun', 'a group of colorful flags hanging from a pole', 'a bunch of balloons hanging from a pole', 'a group of people are holding colorful balloons', 'a bunch of colorful flags hanging from a building', 'a man standing in front of a red gate', 'a man sitting in front of a red gate', 'a man standing in front of a red gate', 'a man standing in front of a red gate', 'a lake with a boat in it', 'a lake with a boat in it', 'a lake with a sun shining over it', 'a view of the ocean and mountains from a helicopter', 'a view of the ocean and mountains from a helicopter', 'a view of the ocean from a helicopter', 'a view of the mountains and water from a helicopter', 'a view of the ocean from a helicopter', 'a long corridor with red tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a long corridor with red tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a long corridor with red tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a long tunnel of red tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a long tunnel with red tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a bamboo tree in the middle of a forest', 'a bamboo tree in the middle of a forest', 'a bamboo tree in the middle of a forest', 'a bamboo tree in the middle of a forest', 'a bamboo tree in the middle of a forest', 'a bamboo tree in the middle of a forest', 'a water mill in the middle of a river', 'a river with a water wheel in the middle', 'a river with a water wheel in the middle', 'a river with a water wheel in the middle', 'a river with a water wheel in it', 'a pond in a japanese garden', 'a pond with a gaze in it', 'a pond in a japanese garden', 'a pond in a japanese garden', 'a pond with a gaze in it', 'a car is parked on the side of the road', 'a green and yellow train', 'a green train is parked on the tracks', 'a green and yellow train', 'a green train is parked on the tracks', 'a group of people standing around a train', 'a blue and yellow train', 'a blue and yellow trolley car', 'a blue and yellow train is parked on the street', 'a train is on the tracks', 'a person standing on a street next to a building', 'a white chair sitting on top of a rock near the ocean', 'a white chair sitting on top of a rock near the ocean', 'a white chair sitting on top of a rock near the ocean', 'a white arch on the beach with blue water', 'a white arch on the beach with blue water', 'a woman in a kimono walking down a street', 'a woman in a kimono walking down a street', 'a woman in a kimono walking down a street', 'a woman in a kimono walking down a street', 'a woman in a kimono walking down a street', 'a woman in a kimonoa walking down a street', 'a red tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a red tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a red tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a long tunnel of red tori tori tori tori tori tori tori tori tori tori tori tori tori tori', 'a large building with many people walking around it', 'a large building with many people walking around it', 'a large building with many people walking around it', 'the largest wooden building in the world', 'a large pagoda with a blue sky in the background', 'a pond with a pagoda in the middle', 'a pond with a pagoda in the ...
#
# Analyzing scenes with Gemini...
#
# Analysis Results:
# ## Travel Guide based on Video Scenes
#
# Here's a structured travel guide derived from the video scene descriptions:
#
# **1. Cityscape with Pagoda**
#
# * **Name:**  Unspecified City (Likely in East Asia)
# * **Description:** A city with a prominent pagoda tower, sometimes seen with a mountain backdrop.  Suggests a blend of urban and natural environments.
# * **Type:** City
# * **Relevant Information:**
#     * **Best time to visit:** Not specified (likely depends on the specific location)
#     * **Type of traveler:**  Those interested in cultural and historical sites, city exploration, and possibly nature.
#     * **Potential local cuisine:**  Not specified (likely East Asian cuisine).
#
# **2. Serene Countryside**
#
# * **Name:** Unspecified Countryside
# * **Description:**  Green fields under blue skies, trees with pink and red blossoms. Suggests a peaceful rural setting.
# * **Type:** Experience
# * **Relevant Information:**
#     * **Best time to participate:** Spring (due to blossoms).
#     * **Who might enjoy it:** Nature lovers, those seeking tranquility.
#
# **3. Festive Atmosphere**
#
# * **Name:** Unspecified Festival/Celebration
# * **Description:** Colorful flags and balloons, people holding balloons.  Indicates a lively festive occasion.
# * **Type:** Experience
# * **Relevant Information:**
#     * **Best time to participate:**  Not specified (depends on the specific festival).
#     * **Who might enjoy it:**  Those who enjoy vibrant cultural celebrations.
#
# **4. Red Gate Encounter**
#
# * **Name:** Red Gate (Possibly a shrine or temple entrance)
# * **Description:** A man interacting with a traditional red gate.  Suggests a cultural or spiritual site.
# * **Type:** Landmark
# * **Relevant Information:**
#     * **Historical/cultural significance:** Not specified (likely related to local traditions).
#     * **Key features:**  Distinct red color, possibly indicative of a specific architectural style.
#
# **5. Lakeside Serenity**
#
# * **Name:** Unspecified Lake
# * **Description:**  A lake with a boat, sunlight reflecting on the water. Implies a peaceful lakeside experience.
# * **Type:** Activity
# * **Relevant Information:**
#     * **Best time to participate:**  Not specified.
#     * **Who might enjoy it:** Those seeking relaxation, boating enthusiasts.
#
# **6. Aerial Coastal Views**
#
# * **Name:** Coastal Region (Ocean and Mountains)
# * **Description:** Helicopter views of the ocean and mountains. Suggests a scenic area ideal for aerial sightseeing.
# * **Type:** Experience
# * **Relevant Information:**
#     * **Best time to participate:** Not specified (likely depends on weather conditions).
#     * **Who might enjoy it:**  Adventure seekers, those who appreciate stunning natural landscapes.
#
# **7. Vermilion Corridor (Fushimi Inari Shrine?)**
#
# * **Name:**  Vermilion Corridor (Potentially Fushimi Inari Shrine in Kyoto, Japan)
# * **Description:** Long corridors and tunnels formed by numerous red torii gates. A visually striking and culturally significant location.
# * **Type:** Landmark
# * **Relevant Information:**
#     * **Historical/cultural significance:**  If Fushimi Inari, dedicated to Inari, the Shinto god of rice, sake, prosperity, and foxes.
#     * **Key features:** Thousands of vibrant red torii gates winding up a mountainside.
#
# **8. Bamboo Forest**
#
# * **Name:** Bamboo Forest
# * **Description:**  Dense bamboo groves.  Creates a tranquil and immersive natural experience.
# * **Type:** Experience
# * **Relevant Information:**
#     * **Best time to participate:** Not specified.
#     * **Who might enjoy it:** Nature lovers, photographers.
#
#
# **9. Water Mill by the River**
#
# * **Name:** Riverside Water Mill
# * **Description:** A water wheel in a river, possibly part of a small village. Suggests a traditional or historical setting.
# * **Type:** Landmark
# * **Relevant Information:**
#     * **Historical/cultural significance:**  Potentially related to historical water-powered technology.
#     * **Key features:**  Functioning water wheel, integration with the river environment.
#
#
# **(Other scenes indicate variations of the above or provide less specific details, such as trains, gardens, city streets, and the Great Wall of China.  These could be incorporated into a more detailed travel itinerary based on further information.)**
